# %% [markdown]
# # Optimizing Profits: Discover Property Treasures Using Cutting-Edge AI and Data Mining
#
# ## Business Problem
#
# ### Introduction:
#
# Welcome to the Property Investment Challenge! Our client, an investment fund, is on a mission to maximize returns on real estate investments. In this dynamic and competitive market, the fund is looking to leverage cutting-edge AI and data mining techniques to identify and invest in properties with the highest potential for profitability. The goal is to optimize the allocation of resources and strategically select properties that can yield substantial returns on investment.
#
# ### Challenge Overview:
#
# The investment fund is planning to make a significant number of property investments, and the key to success lies in the ability to identify properties that offer substantial returns. The challenge is rooted in a vast dataset that spans the last 23 years, encompassing millions of property sales. The fund envisions a solution that can effectively segment these properties, enabling them to leverage sophisticated machine learning and analytics to quickly identify target properties for investment.
#
# ### Key Objectives:
#
# 1. **Predictive Modeling:**
#    - Develop robust machine learning models capable of accurately predicting property sale prices. These models should take into account various factors such as location, estimated price, and other relevant features.
#
# 2. **Segmentation:**
#    - After predicting sale prices, segment the properties into four distinct categories based on the calculated gain. The gain is calculated using the formula: `(Sale price - Estimated price)/100`.
#      - **Segment 0: Premium Properties 💰🏰**
#      - **Segment 1: Valuable Properties 💎🏡**
#      - **Segment 2: Standard Properties 🏘️💸**
#      - **Segment 3: Budget Properties 🏠💵**
#
# ### Dataset:
#
# Participants will be provided with a comprehensive property dataset spanning the last 23 years. This dataset includes information such as property location, estimated price, selling price, and other relevant details.
#
# ### Expected Outcome:
#
# The investment fund anticipates a solution that can not only accurately predict property sale prices but also categorize them into distinct segments. This segmentation will empower the fund to make well-informed decisions, strategically investing in properties that align with their overarching goal of maximizing returns.
#
# ### Evaluation:
#
# Submissions will be assessed based on the performance metric relevant to regression tasks. The chosen metric should accurately reflect the model's ability to predict continuous numerical values, such as property sale prices. Participants are encouraged to select a metric aligned with the competition's goals and dataset characteristics, using it as a guiding measure for model accuracy and improvement.
#
# Let the challenge begin, and may the best solution unlock the potential of property treasures! 🏡💎

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pip install requests
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: requests in c:\users\lenovo\appdata\roaming\python\python310\site-packages (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\lenovo\appdata\roaming\python\python310\site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\lenovo\appdata\roaming\python\python310\site-packages (from requests) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\lenovo\appdata\roaming\python\python310\site-packages (from requests) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\lenovo\appdata\roaming\python\python310\site-packages (from requests) (2023.7.22)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.3.2 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install -r requirements.txt
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: requests in c:\users\lenovo\appdata\roaming\python\python310\site-packages (from -r requirements.txt (line 1)) (2.31.0)
# Requirement already satisfied: numpy in c:\users\lenovo\appdata\roaming\python\python310\site-packages (from -r requirements.txt (line 2)) (1.26.3)
# Requirement already satisfied: pandas in c:\program files\python310\lib\site-packages (from -r requirements.txt (line 3)) (1.5.2)
# Requirement already satisfied: matplotlib in c:\users\lenovo\appdata\roaming\python\python310\site-packages (from -r requirements.txt (line 4)) (3.8.2)
# Requirement already satisfied: seaborn in c:\users\lenovo\appdata\roaming\python\python310\site-packages (from -r requirements.txt (line 5)) (0.13.0)
# Collecting fastapi (from -r requirements.txt (line 6))
#   Downloading fastapi-0.109.2-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: notebook in c:\users\lenovo\appdata\roaming\python\python310\site-packages (from -r requirements.txt (line 7)) (7.0.6)
# Requirement already satisfied: streamlit in c:\users\lenovo\appdata\roaming\python\python310\site-packages (from -r requirements.txt (line 8)) (1.28.1)
# Requirement already satisfied: scikit-learn in c:\users\lenovo\appdata\roaming\python\python310\site-packages (from -r requirements.txt (line 9)) (1.2.1)
# Requirement already satisfied: scipy in c:\users\lenovo\appdata\roaming\python\python310\site-packages (from -r requirements.txt (line 10)) (1.11.3)
# Requirement already satisfied: joblib in c:\users\lenovo\appdata\roaming\python\python310\site-packages (from -r requirements.txt (line 11)) (1.3.2)
# Collecting docker (from -r requirements.txt (line 12))
#   Downloading docker-7.0.0-py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\lenovo\appdata\roaming\python\python310\site-packages (from requests->-r requirements.txt (line 1)) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\lenovo\appdata\roaming\python\python310\site-packages (from requests->-r requirements.txt (line 1)) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\lenovo\appdata\roaming\python\python310\site-packages (from requests->-r requirements.txt (line 1)) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\lenovo\appdata\roaming\python\python310\site-packages (from requests->-r requirements.txt (line 1)) (2023.7.22)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\lenovo\appdata\roaming\python\python310\site-packages (from pandas->-r requirements.txt (line 3)) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\program files\python310\lib\site-packages (from pandas->-r requirements.txt (line 3)) (2022.6)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\lenovo\appdata\roaming\python\python310\site-packages (from matplotlib->-r requirements.txt (line 4)) (1.0.6)
# Requirement already satisfied: cycler>=0.10 in c:\users\lenovo\appdata\roaming\python\python310\site-packages (from matplotlib->-r requirements.txt (line 4)) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\lenovo\appdata\roaming\python\python310\site-packages (from matplotlib->-r requirements.txt (line 4)) (4.38.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\lenovo\appdata\roaming\python\python310\site-packages (from matplotlib->-r requirements.txt (line 4)) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\lenovo\appdata\roaming\python\python310\site-packages (from matplotlib->-r requirements.txt (line 4)) (21.3)
# Requirement already satisfied: pillow>=8 in c:\users\lenovo\appdata\roaming\python\python310\site-packages (from matplotlib->-r requirements.txt (line 4)) (9.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\lenovo\appdata\roaming\python\python310\site-packages (from matplotlib->-r requirements.txt (line 4)) (3.0.9)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4 in c:\users\lenovo\appdata\roaming\python\python310\site-packages (from fastapi->-r requirements.txt (line 6)) (2.6.1)
# Collecting starlette<0.37.0,>=0.36.3 (from fastapi->-r requirements.txt (line 6))
#   Downloading starlette-0.36.3-py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\lenovo\appdata\roaming\python\python310\site-packages (from fastapi->-r requirements.txt (line 6)) (4.8.0)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in c:\users\lenovo\appdata\roaming\python\python310\site-packages (from notebook->-r requirements.txt (line 7)) (2.11.1)
# Requirement already satisfied: jupyterlab-server<3,>=2.22.1 in c:\users\lenovo\appdata\roaming\python\python310\site-packages (from notebook->-r requirements.txt (line 7)) (2.25.2)
# Requirement already satisfied: jupyterlab<5,>=4.0.2 in c:\users\lenovo\appdata\roaming\python\python310\site-packages (from notebook->-r requirements.txt (line 7)) (4.0.9)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in c:\users\lenovo\appdata\roaming\python\python310\site-packages (from notebook->-r requirements.txt (line 7)) (0.2.3)
# Requirement already satisfied: tornado>=6.2.0 in c:\users\lenovo\appdata\roaming\python\python310\site-packages (from notebook->-r requirements.txt (line 7)) (6.2)
# Requirement already satisfied: altair<6,>=4.0 in c:\users\lenovo\appdata\roaming\python\python310\site-packages (from streamlit->-r requirements.txt (line 8)) (5.1.2)
# Requirement already satisfied: blinker<2,>=1.0.0 in c:\users\lenovo\appdata\roaming\python\python310\site-packages (from streamlit->-r requirements.txt (line 8)) (1.7.0)
# Requirement already satisfied: cachetools<6,>=4.0 in c:\users\lenovo\appdata\roaming\python\python310\site-packages (from streamlit->-r requirements.txt (line 8)) (5.3.2)
# Requirement already satisfied: click<9,>=7.0 in c:\program files\python310\lib\site-packages (from streamlit->-r requirements.txt (line 8)) (8.1.3)
# Requirement already satisfied: importlib-metadata<7,>=1.4 in c:\users\lenovo\appdata\roaming\python\python310\site-packages (from streamlit->-r requirements.txt (line 8)) (6.8.0)
# Requirement already satisfied: protobuf<5,>=3.20 in c:\users\lenovo\appdata\roaming\python\python310\site-packages (from streamlit->-r requirements.txt (line 8)) (3.20.3)
# Requirement already satisfied: pyarrow>=6.0 in c:\users\lenovo\appdata\roaming\python\python310\site-packages (from streamlit->-r requirements.txt (line 8)) (14.0.1)
# Requirement already satisfied: rich<14,>=10.14.0 in c:\users\lenovo\appdata\roaming\python\python310\site-packages (from streamlit->-r requirements.txt (line 8)) (13.6.0)
# Requirement already satisfied: tenacity<9,>=8.1.0 in c:\users\lenovo\appdata\roaming\python\python310\site-packages (from streamlit->-r requirements.txt (line 8)) (8.2.3)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\users\lenovo\appdata\roaming\python\python310\site-packages (from streamlit->-r requirements.txt (line 8)) (0.10.2)
# Requirement already satisfied: tzlocal<6,>=1.1 in c:\users\lenovo\appdata\roaming\python\python310\site-packages (from streamlit->-r requirements.txt (line 8)) (5.2)
# Requirement already satisfied: validators<1,>=0.2 in c:\users\lenovo\appdata\roaming\python\python310\site-packages (from streamlit->-r requirements.txt (line 8)) (0.22.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in c:\users\lenovo\appdata\roaming\python\python310\site-packages (from streamlit->-r requirements.txt (line 8)) (3.1.40)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in c:\users\lenovo\appdata\roaming\python\python310\site-packages (from streamlit->-r requirements.txt (line 8)) (0.8.1b0)
# Requirement already satisfied: watchdog>=2.1.5 in c:\users\lenovo\appdata\roaming\python\python310\site-packages (from streamlit->-r requirements.txt (line 8)) (3.0.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\lenovo\appdata\roaming\python\python310\site-packages (from scikit-learn->-r requirements.txt (line 9)) (3.2.0)
# Requirement already satisfied: pywin32>=304 in c:\users\lenovo\appdata\roaming\python\python310\site-packages (from docker->-r requirements.txt (line 12)) (304)
# Requirement already satisfied: jinja2 in c:\users\lenovo\appdata\roaming\python\python310\site-packages (from altair<6,>=4.0->streamlit->-r requirements.txt (line 8)) (3.1.2)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\lenovo\appdata\roaming\python\python310\site-packages (from altair<6,>=4.0->streamlit->-r requirements.txt (line 8)) (4.20.0)
# Requirement already satisfied: toolz in c:\users\lenovo\appdata\roaming\python\python310\site-packages (from altair<6,>=4.0->streamlit->-r requirements.txt (line 8)) (0.12.0)
# Requirement already satisfied: colorama in c:\users\lenovo\appdata\roaming\python\python310\site-packages (from click<9,>=7.0->streamlit->-r requirements.txt (line 8)) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\lenovo\appdata\roaming\python\python310\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit->-r requirements.txt (line 8)) (4.0.11)
# Requirement already satisfied: zipp>=0.5 in c:\users\lenovo\appdata\roaming\python\python310\site-packages (from importlib-metadata<7,>=1.4->streamlit->-r requirements.txt (line 8)) (3.17.0)
# Requirement already satisfied: anyio>=3.1.0 in c:\users\lenovo\appdata\roaming\python\python310\site-packages (from jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 7)) (4.1.0)
# Requirement already satisfied: argon2-cffi in c:\users\lenovo\appdata\roaming\python\python310\site-packages (from jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 7)) (21.3.0)
# Requirement already satisfied: jupyter-client>=7.4.4 in c:\users\lenovo\appdata\roaming\python\python310\site-packages (from jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 7)) (8.6.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\lenovo\appdata\roaming\python\python310\site-packages (from jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 7)) (5.5.0)
# Requirement already satisfied: jupyter-events>=0.9.0 in c:\users\lenovo\appdata\roaming\python\python310\site-packages (from jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 7)) (0.9.0)
# Requirement already satisfied: jupyter-server-terminals in c:\users\lenovo\appdata\roaming\python\python310\site-packages (from jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 7)) (0.4.4)
# Requirement already satisfied: nbconvert>=6.4.4 in c:\users\lenovo\appdata\roaming\python\python310\site-packages (from jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 7)) (7.11.0)
# Requirement already satisfied: nbformat>=5.3.0 in c:\users\lenovo\appdata\roaming\python\python310\site-packages (from jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 7)) (5.9.2)
# Requirement already satisfied: overrides in c:\users\lenovo\appdata\roaming\python\python310\site-packages (from jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 7)) (7.4.0)
# Requirement already satisfied: prometheus-client in c:\users\lenovo\appdata\roaming\python\python310\site-packages (from jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 7)) (0.14.1)
# Requirement already satisfied: pywinpty in c:\users\lenovo\appdata\roaming\python\python310\site-packages (from jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 7)) (2.0.6)
# Requirement already satisfied: pyzmq>=24 in c:\users\lenovo\appdata\roaming\python\python310\site-packages (from jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 7)) (25.1.1)
# Requirement already satisfied: send2trash>=1.8.2 in c:\users\lenovo\appdata\roaming\python\python310\site-packages (from jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 7)) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\lenovo\appdata\roaming\python\python310\site-packages (from jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 7)) (0.15.0)
# Requirement already satisfied: traitlets>=5.6.0 in c:\users\lenovo\appdata\roaming\python\python310\site-packages (from jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 7)) (5.14.0)
# Requirement already satisfied: websocket-client in c:\users\lenovo\appdata\roaming\python\python310\site-packages (from jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 7)) (1.6.4)
# Requirement already satisfied: async-lru>=1.0.0 in c:\users\lenovo\appdata\roaming\python\python310\site-packages (from jupyterlab<5,>=4.0.2->notebook->-r requirements.txt (line 7)) (2.0.4)
# Requirement already satisfied: ipykernel in c:\users\lenovo\appdata\roaming\python\python310\site-packages (from jupyterlab<5,>=4.0.2->notebook->-r requirements.txt (line 7)) (6.15.1)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in c:\users\lenovo\appdata\roaming\python\python310\site-packages (from jupyterlab<5,>=4.0.2->notebook->-r requirements.txt (line 7)) (2.2.1)
# Requirement already satisfied: tomli in c:\users\lenovo\appdata\roaming\python\python310\site-packages (from jupyterlab<5,>=4.0.2->notebook->-r requirements.txt (line 7)) (2.0.1)
# Requirement already satisfied: babel>=2.10 in c:\users\lenovo\appdata\roaming\python\python310\site-packages (from jupyterlab-server<3,>=2.22.1->notebook->-r requirements.txt (line 7)) (2.13.1)
# Requirement already satisfied: json5>=0.9.0 in c:\users\lenovo\appdata\roaming\python\python310\site-packages (from jupyterlab-server<3,>=2.22.1->notebook->-r requirements.txt (line 7)) (0.9.14)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\lenovo\appdata\roaming\python\python310\site-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi->-r requirements.txt (line 6)) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.2 in c:\users\lenovo\appdata\roaming\python\python310\site-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi->-r requirements.txt (line 6)) (2.16.2)
# Requirement already satisfied: six>=1.5 in c:\users\lenovo\appdata\roaming\python\python310\site-packages (from python-dateutil>=2.8.1->pandas->-r requirements.txt (line 3)) (1.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\lenovo\appdata\roaming\python\python310\site-packages (from rich<14,>=10.14.0->streamlit->-r requirements.txt (line 8)) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\lenovo\appdata\roaming\python\python310\site-packages (from rich<14,>=10.14.0->streamlit->-r requirements.txt (line 8)) (2.16.1)
# Requirement already satisfied: tzdata in c:\users\lenovo\appdata\roaming\python\python310\site-packages (from tzlocal<6,>=1.1->streamlit->-r requirements.txt (line 8)) (2023.3)
# Requirement already satisfied: sniffio>=1.1 in c:\users\lenovo\appdata\roaming\python\python310\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 7)) (1.3.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\lenovo\appdata\roaming\python\python310\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 7)) (1.2.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\lenovo\appdata\roaming\python\python310\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit->-r requirements.txt (line 8)) (5.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\lenovo\appdata\roaming\python\python310\site-packages (from jinja2->altair<6,>=4.0->streamlit->-r requirements.txt (line 8)) (2.1.1)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\lenovo\appdata\roaming\python\python310\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit->-r requirements.txt (line 8)) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\lenovo\appdata\roaming\python\python310\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit->-r requirements.txt (line 8)) (2023.11.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\lenovo\appdata\roaming\python\python310\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit->-r requirements.txt (line 8)) (0.31.1)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\lenovo\appdata\roaming\python\python310\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit->-r requirements.txt (line 8)) (0.13.2)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\lenovo\appdata\roaming\python\python310\site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 7)) (3.11.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\users\lenovo\appdata\roaming\python\python310\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 7)) (2.0.7)
# Requirement already satisfied: pyyaml>=5.3 in c:\users\lenovo\appdata\roaming\python\python310\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 7)) (6.0.1)
# Requirement already satisfied: rfc3339-validator in c:\users\lenovo\appdata\roaming\python\python310\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 7)) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\lenovo\appdata\roaming\python\python310\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 7)) (0.1.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\lenovo\appdata\roaming\python\python310\site-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit->-r requirements.txt (line 8)) (0.1.2)
# Requirement already satisfied: beautifulsoup4 in c:\users\lenovo\appdata\roaming\python\python310\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 7)) (4.11.1)
# Requirement already satisfied: bleach!=5.0.0 in c:\users\lenovo\appdata\roaming\python\python310\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 7)) (5.0.1)
# Requirement already satisfied: defusedxml in c:\users\lenovo\appdata\roaming\python\python310\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 7)) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\lenovo\appdata\roaming\python\python310\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 7)) (0.2.2)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\lenovo\appdata\roaming\python\python310\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 7)) (3.0.2)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\lenovo\appdata\roaming\python\python310\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 7)) (0.6.6)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\lenovo\appdata\roaming\python\python310\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 7)) (1.5.0)
# Requirement already satisfied: tinycss2 in c:\users\lenovo\appdata\roaming\python\python310\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 7)) (1.1.1)
# Requirement already satisfied: fastjsonschema in c:\users\lenovo\appdata\roaming\python\python310\site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 7)) (2.16.1)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\lenovo\appdata\roaming\python\python310\site-packages (from argon2-cffi->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 7)) (21.2.0)
# Requirement already satisfied: debugpy>=1.0 in c:\users\lenovo\appdata\roaming\python\python310\site-packages (from ipykernel->jupyterlab<5,>=4.0.2->notebook->-r requirements.txt (line 7)) (1.6.2)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\lenovo\appdata\roaming\python\python310\site-packages (from ipykernel->jupyterlab<5,>=4.0.2->notebook->-r requirements.txt (line 7)) (8.18.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\lenovo\appdata\roaming\python\python310\site-packages (from ipykernel->jupyterlab<5,>=4.0.2->notebook->-r requirements.txt (line 7)) (0.1.3)
# Requirement already satisfied: nest-asyncio in c:\users\lenovo\appdata\roaming\python\python310\site-packages (from ipykernel->jupyterlab<5,>=4.0.2->notebook->-r requirements.txt (line 7)) (1.5.5)
# Requirement already satisfied: psutil in c:\users\lenovo\appdata\roaming\python\python310\site-packages (from ipykernel->jupyterlab<5,>=4.0.2->notebook->-r requirements.txt (line 7)) (5.9.1)
# Requirement already satisfied: webencodings in c:\users\lenovo\appdata\roaming\python\python310\site-packages (from bleach!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 7)) (0.5.1)
# Requirement already satisfied: decorator in c:\users\lenovo\appdata\roaming\python\python310\site-packages (from ipython>=7.23.1->ipykernel->jupyterlab<5,>=4.0.2->notebook->-r requirements.txt (line 7)) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\lenovo\appdata\roaming\python\python310\site-packages (from ipython>=7.23.1->ipykernel->jupyterlab<5,>=4.0.2->notebook->-r requirements.txt (line 7)) (0.18.1)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\lenovo\appdata\roaming\python\python310\site-packages (from ipython>=7.23.1->ipykernel->jupyterlab<5,>=4.0.2->notebook->-r requirements.txt (line 7)) (3.0.41)
# Requirement already satisfied: stack-data in c:\users\lenovo\appdata\roaming\python\python310\site-packages (from ipython>=7.23.1->ipykernel->jupyterlab<5,>=4.0.2->notebook->-r requirements.txt (line 7)) (0.3.0)
# Requirement already satisfied: fqdn in c:\users\lenovo\appdata\roaming\python\python310\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 7)) (1.5.1)
# Requirement already satisfied: isoduration in c:\users\lenovo\appdata\roaming\python\python310\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 7)) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\lenovo\appdata\roaming\python\python310\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 7)) (2.4)
# Requirement already satisfied: uri-template in c:\users\lenovo\appdata\roaming\python\python310\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 7)) (1.3.0)
# Requirement already satisfied: webcolors>=1.11 in c:\users\lenovo\appdata\roaming\python\python310\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 7)) (1.13)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\lenovo\appdata\roaming\python\python310\site-packages (from argon2-cffi-bindings->argon2-cffi->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 7)) (1.15.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\lenovo\appdata\roaming\python\python310\site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 7)) (2.3.2.post1)
# Requirement already satisfied: pycparser in c:\users\lenovo\appdata\roaming\python\python310\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 7)) (2.21)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\lenovo\appdata\roaming\python\python310\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyterlab<5,>=4.0.2->notebook->-r requirements.txt (line 7)) (0.8.3)
# Requirement already satisfied: wcwidth in c:\users\lenovo\appdata\roaming\python\python310\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel->jupyterlab<5,>=4.0.2->notebook->-r requirements.txt (line 7)) (0.2.13)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\lenovo\appdata\roaming\python\python310\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 7)) (1.3.0)
# Requirement already satisfied: executing in c:\users\lenovo\appdata\roaming\python\python310\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyterlab<5,>=4.0.2->notebook->-r requirements.txt (line 7)) (0.9.1)
# Requirement already satisfied: asttokens in c:\users\lenovo\appdata\roaming\python\python310\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyterlab<5,>=4.0.2->notebook->-r requirements.txt (line 7)) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\lenovo\appdata\roaming\python\python310\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyterlab<5,>=4.0.2->notebook->-r requirements.txt (line 7)) (0.2.2)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in c:\users\lenovo\appdata\roaming\python\python310\site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->-r requirements.txt (line 7)) (2.8.19.14)
# Downloading fastapi-0.109.2-py3-none-any.whl (92 kB)
#    ---------------------------------------- 92.1/92.1 kB 186.8 kB/s eta 0:00:00
# Downloading docker-7.0.0-py3-none-any.whl (147 kB)
#    -------------------------------------- 147.6/147.6 kB 313.5 kB/s eta 0:00:00
# Downloading starlette-0.36.3-py3-none-any.whl (71 kB)
#    ---------------------------------------- 71.5/71.5 kB 437.4 kB/s eta 0:00:00
# Installing collected packages: starlette, docker, fastapi
# Successfully installed docker-7.0.0 fastapi-0.109.2 starlette-0.36.3
# [notice] A new release of pip is available: 23.3.2 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# # 1. Data Acquisition

# %%
import os
import requests
from credentials import ACCESS, BUCKET_NAME, DATABASE_URL


# IMPORTANT: Credentials are not shared in this public notebook.

# with your own credentials if you intend to run this code.

# Never share sensitive information like credentials publicly.

# See Rest of code

# %%
file_names = [f'pucon24_ai_train_{i}.csv' for i in range(1, 13)]
file_names += ['pucon24-ai-test.csv', 'pucon24-ai-sample_submission.csv', 'pucon24_ai_description.txt']
file_names
# Out:
# ['pucon24_ai_train_1.csv',
#  'pucon24_ai_train_2.csv',
#  'pucon24_ai_train_3.csv',
#  'pucon24_ai_train_4.csv',
#  'pucon24_ai_train_5.csv',
#  'pucon24_ai_train_6.csv',
#  'pucon24_ai_train_7.csv',
#  'pucon24_ai_train_8.csv',
#  'pucon24_ai_train_9.csv',
#  'pucon24_ai_train_10.csv',
#  'pucon24_ai_train_11.csv',
#  'pucon24_ai_train_12.csv',
#  'pucon24-ai-test.csv',
#  'pucon24-ai-sample_submission.csv',
#  'pucon24_ai_description.txt']

# %%
def access_dataset(file_name):
    url = f'{DATABASE_URL}/{ACCESS}/{BUCKET_NAME}/{file_name}'
    response = requests.get(url)
    
    if response.status_code == 200:
        with open(f'./Dataset/{file_name}', 'wb') as file:
            file.write(response.content)
        print(f'File {file_name} saved successfully.')
    else:
        print(f'Failed to download file. Status code: {response.status_code}')

# %%
access_dataset('pucon24-ai-test.csv')
# Out:
# File pucon24-ai-test.csv saved successfully.

# %%
for file_name in file_names:
    access_dataset(file_name)

# %%
df = pd.DataFrame()

for i in range(1, 13):
    tmp_df = pd.read_csv(f'./Dataset/pucon24_ai_train_{i}.csv')
    df = pd.concat([df, tmp_df], axis=1)

# %%
df.head()
# Out:
#                   Date          crime_rate renovation_level  Year  \
# 0  2009-01-02-00:00:00  2.6568262407789027            Minor  2009
# 1  2009-01-02-00:00:00   5.328727031244374            Basic  2009
# 2  2009-01-02-00:00:00   4.037758682930219            Basic  2009
# 3  2009-01-02-00:00:00   2.085308997846847        Extensive  2009
# 4  02-01-2009-00:00:00   4.397712193695299          Partial  2009
#
#               Address    num_rooms       Property amenities_rating  \
# 0    40 ETTL LN UT 24    Two rooms          Condo         Mediocre
# 1         18 BAUER RD  Three rooms  Single Family           Superb
# 2  48 HIGH VALLEY RD.  Three rooms  Single Family     Satisfactory
# 3       56 MERIDEN RD  Three rooms  Single Family           Superb
# 4     13 CELENTANO DR  Three rooms  Single Family    Below Average
#
#          carpet_area nearby_restaurants  ... carpet_area nearby_restaurants  \
# 0              760.0               19.0  ...       933.0               14.0
# 1  7967.337677159014               17.0  ...       975.0                1.0
# 2              982.0                1.0  ...      1073.0                2.0
# 3              976.0                5.0  ...      1022.0                5.0
# 4              947.0               14.0  ...       956.0               13.0
#
#    public_transport_availability property_tax_rate distance_to_school  \
# 0                      Scattered          1.003979           0.128864
# 1                       Abundant          1.003979           8.864996
# 2                     Inadequate          1.003979           5.792544
# 3                         Sparse          1.003979           7.198714
# 4                      Extensive          1.003979           3.833746
#
#     Locality     Residential Estimated Value Sale Price  \
# 0     Groton  Detached House        269430.0   650000.0
# 1  Waterbury  Detached House         78180.0   140000.0
# 2  Greenwich  Detached House        787290.0  1349000.0
# 3   Columbia  Detached House        144900.0   172750.0
# 4  Watertown  Detached House        107100.0   217000.0
#
#                                       specifications
# 0  In 2022, this residential located in Groton at...
# 1  In 2022, this residential located in Waterbury...
# 2  In 2022, this residential located in Greenwich...
# 3  In 2022, this residential located in Columbia ...
# 4  In 2022, this residential located in Watertown...
#
# [5 rows x 216 columns]

# %%
df.to_csv('./Dataset/training.csv')
